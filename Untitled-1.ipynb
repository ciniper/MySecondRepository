# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Game_Logs_Quarterback.csv")

df
# Out:
#                    Player Id             Name Position  Year     Season  Week  \
# 0       brandonallen/2555365   Allen, Brandon       QB  2019  Preseason     1
# 1       brandonallen/2555365   Allen, Brandon       QB  2019  Preseason     2
# 2       brandonallen/2555365   Allen, Brandon       QB  2018  Preseason     1
# 3       brandonallen/2555365   Allen, Brandon       QB  2018  Preseason     2
# 4       brandonallen/2555365   Allen, Brandon       QB  2018  Preseason     3
# ...                      ...              ...      ...   ...        ...   ...
# 10056  loganwoodside/2560942  Woodside, Logan       QB  2019  Preseason     2
# 10057  loganwoodside/2560942  Woodside, Logan       QB  2018  Preseason     1
# 10058  loganwoodside/2560942  Woodside, Logan       QB  2018  Preseason     2
# 10059  loganwoodside/2560942  Woodside, Logan       QB  2018  Preseason     3
# 10060  loganwoodside/2560942  Woodside, Logan       QB  2018  Preseason     4
#
# ...

# %%
df_tb = df[df["Name"]=="Brady, Tom"]

# %%
plt.hist(df_tb["Passing Yards"], bins = 10,edgecolor="black")
plt.xticks(np.arange(0,500,100))
# Out:
# ([<matplotlib.axis.XTick at 0x1b4186e5910>,
# ...
#  [Text(0, 0, '--'),
#   Text(100, 0, '122'),
#   Text(200, 0, '353'),
#   Text(300, 0, ''),
#   Text(400, 0, '')])
